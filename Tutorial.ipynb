# %% [markdown]
# <a href="https://colab.research.google.com/github/mahdimplus/Covid-19/blob/master/Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Introduction to DeepRetroMoCo**
# Mahdi Mobarak Abadi
#
# This is a short tutorial to get you started with [DRM](https://github.com/mahdimplus/DeepRetroMoco): deep-learning based registration.
#
# ### **Outline**
#
#
# - **Prepared data**
# first we will learn to how prepared the functional data for network.
#
# - **Visulize functional data**
# We will then show how functional data can be presented in 4 dimensions and also will train to work with our data generator, presenting a more complex scenario.
# - **2D motion correction based on centerline (Rigid)**
# We will illustrate the FC method that acts like a preprocess for our network. it regularizes the data in the Axial view across the Z dimension.
# - **Using network**
# we will learn more advanced topics, including network parameters, reference volume, validation generator.
# - **Validation**
# Finally, we close with more parameters such as tSNR, DVARS, FSL gold standard.

# %%
pip install nbimporter

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import sys
sys.path.append('1hrHgFuXHPEWBBxJ2h84_LjducYqQ5rkd')

# %%
import sys
import os

py_file_location = "/content/drive/My Drive/functions.ipynb"
sys.path.append(os.path.abspath(py_file_location))

# %%
# !pip install pydrive                             # Package to use Google Drive API - not installed in Colab VM by default
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# %%
from google.colab import auth                    # Other necessary packages
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()                         # Follow prompt in the authorization process
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()

# %%
https://colab.research.google.com/drive/1hrHgFuXHPEWBBxJ2h84_LjducYqQ5rkd?usp=sharing

# %%
drive = GoogleDrive(gauth)
your_module = drive.CreateFile({"id": "1hrHgFuXHPEWBBxJ2h84_LjducYqQ5rkd"})   # "your_module_file_id" is the part after "id=" in the shareable link
your_module.GetContentFile("functions.py")          # Save the .py module file to Colab VM
import functions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-6545f3387b9a> in <module>()
#       2 your_module = drive.CreateFile({"id": "1hrHgFuXHPEWBBxJ2h84_LjducYqQ5rkd"})   # "your_module_file_id" is the part after "id=" in the shareable link
#       3 your_module.GetContentFile("functions.py")          # Save the .py module file to Colab VM
# ----> 4 import functions
#
# /root/functions.py in <module>()
# ...

# %%
import nbimporter
import functions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-4559c30fa2c2> in <module>()
#       1 import nbimporter
# ----> 2 import functions
#
# /root/functions.py in <module>()
# ----> 1 {"cells":[{"cell_type":"markdown","source":["[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mahdimplus/DeepRetroMoco/blob/main/functions.ipynb)"],"metadata":{"id":"IP1OR5KA4m2w"}},{"cell_type":"code","source":["pip install voxelmorph"],"metadata":{"id":"EAnDfgvm54v_","outputId":"281864c9-98f7-4015-fd3a-5cc92fa35ff9","colab":{"base_uri":"https://localhost:8080/"}},"execution_count":null,"outputs":[{"output_type":"stream","name":"stdout","text":["Collecting voxelmorph\n","  Downloading voxelmorph-0.1-py3-none-any.whl (75 kB)\n","\u001b[K ...
#
# NameError: name 'null' is not defined

# %%
# install Anaconda3
# !wget -qO ac.sh https://repo.anaconda.com/archive/Anaconda3-2020.07-Linux-x86_64.sh 
# !bash ./ac.sh -b

# a fake google.colab library
# !ln -s /usr/local/lib/python3.6/dist-packages/google \
       /root/anaconda3/lib/python3.8/site-packages/google

# start jupyterlab, which now has Python3 = 3.8
# !nohup /root/anaconda3/bin/jupyter-lab --ip=0.0.0.0&

# access through ngrok, click the link
# !pip install pyngrok -q
from pyngrok import ngrok
print(ngrok.connect(8888))
# Out:
# PREFIX=/root/anaconda3
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /root/anaconda3
#
#   added / updated specs:
#     - _ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#     - _libgcc_mutex==0.1=main
#     - alabaster==0.7.12=py_0
#     - anaconda-client==1.7.2=py38_0
#     - anaconda-navigator==1.9.12=py38_0
#     - anaconda-project==0.8.4=py_0
#     - anaconda==2020.07=py38_0
#     - argh==0.26.2=py38_0
#     - asn1crypto==1.3.0=py38_0
#     - astroid==2.4.2=py38_0
#     - astropy==4.0.1.post1=py38h7b6447c_1
#     - atomicwrites==1.4.0=py_0
#     - attrs==19.3.0=py_0
#     - autopep8==1.5.3=py_0
#     - babel==2.8.0=py_0
#     - backcall==0.2.0=py_0
#     - backports.functools_lru_cache==1.6.1=py_0
#     - backports.shutil_get_terminal_size==1.0.0=py38_2
#     - backports.tempfile==1.0=py_1
#     - backports.weakref==1.0.post1=py_1
#     - backports==1.0=py_2
#     - beautifulsoup4==4.9.1=py38_0
#     - bitarray==1.4.0=py38h7b6447c_0
# ...

# %%
# Install the python version
# !apt-get install python3.7

# Select the version
# !python3.7 setup.py
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3.7 is already the newest version (3.7.12-1+bionic1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# python3.7: can't open file 'setup.py': [Errno 2] No such file or directory

# %%
pip install functions

# %%
import functions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-01a49f1064bc> in <module>()
# ----> 1 import functions
#
# /root/functions.py in <module>()
# ----> 1 {"cells":[{"cell_type":"markdown","source":["[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mahdimplus/DeepRetroMoco/blob/main/functions.ipynb)"],"metadata":{"id":"IP1OR5KA4m2w"}},{"cell_type":"code","source":["pip install voxelmorph"],"metadata":{"id":"EAnDfgvm54v_","outputId":"281864c9-98f7-4015-fd3a-5cc92fa35ff9","colab":{"base_uri":"https://localhost:8080/"}},"execution_count":null,"outputs":[{"output_type":"stream","name":"stdout","text":["Collecting voxelmorph\n","  Downloading voxelmorph-0.1-py3-none-any.whl (75 kB)\n","\u001b[K ...
#
# NameError: name 'null' is not defined
